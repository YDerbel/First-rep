# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __YASSINE DERBEL__ <br> My desired occupation is a data science consultant.

# %% [markdown]
# *I am interested in data science because a data scientist can make of raw data insights to guide decision-makers to grow the business and recognize market trends.*

# %% [markdown]
# ### The code below compare two numbers and return a string describing the result.

# %%
def compare(x,y):
    if x > y:
        return 'the first parameter is greater than the second one'
    if x < y:
        return 'the second parameter is greater than the first one'
    return 'the two parameters are equal'
print(compare(5,5))
# Out:
# the two parameters are equal

# %% [markdown]
# ***************
# - First bullet point
#      - Table
#
#
# | IBM Gallery | An image |
# | ------ | ------ |
# |cell|cell|
#
#
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
#
# <img src="data:image/png;base64,..." alt="Alt text that describes the graphic" title="IBM" />
